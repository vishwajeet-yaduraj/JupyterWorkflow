# %% [markdown]
# # Pie plots

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use('fivethirtyeight') 

labels = ['Java', 'Python', 'SQL', 'HTML/CSS', 'JavaScript']
series =  [35917, 36443, 47544, 55466, 59219]   
explode = [0,0.1,0,0,0.1]

plt.pie(series,labels = labels, explode = explode, shadow = True, autopct='%1.1f%%',
        wedgeprops={'edgecolor': 'black'})

plt.title('A Pie Chart')
# Out:
# Text(0.5, 1.0, 'A Pie Chart')

# %%
# 5833, 7201, 7331, 7920, 18017, 18523, 20524, 23030, 27097, 31991,
# 'Assembly', 'Go', 'Ruby', 'Other(s):', 'C', 'TypeScript', 'C++', 'PHP', 'C#', 'Bash/Shell/PowerShell',

# %% [markdown]
# # Stack Plots

# %%
minutes = [1, 2, 3, 4, 5, 6, 7, 8, 9]

player1 = [8, 6, 5, 5, 4, 2, 1, 1, 0]
player2 = [0, 1, 2, 2, 2, 4, 4, 4, 4]
player3 = [0, 1, 1, 1, 2, 2, 3, 3, 4]

labels = [ 'player1', 'player2', 'player3']

# %%
plt.stackplot(minutes, player1, player2, player3, labels = labels)
plt.title('A stack plot')
plt.legend()
